# %%
import pandas as pd
import numpy as np

# %%
col=['User','Item','Rating','Timestamp']
rv=pd.read_csv('ratings_Electronics.csv',names=col)
rv.head()
# Out:
#              User        Item  Rating     Timestamp
# 0   AKM1MP6P0OYPR  0132793040     5.0  1.365811e+09
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1.341101e+09
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1.367194e+09
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1.374451e+09
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1.334707e+09

# %%
rv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880251 entries, 0 to 880250
# Data columns (total 4 columns):
# User         880251 non-null object
# Item         880250 non-null object
# Rating       880250 non-null float64
# Timestamp    880250 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 26.9+ MB

# %%
rv.shape
# Out:
# (880251, 4)

# %%
import seaborn as sns

# %%
rv['Rating'].hist()

# %%
#It can be seen that higher ratings are more common amongst users and rating 8 has been rated highest number of times

# %% [markdown]
# For more accuracy considering only results of the users who rated more than 50 times

# %%
counts1 = rv['User'].value_counts()
rv = rv[rv['User'].isin(counts1[counts1 >=50].index)]

# %%
rv.head()
# Out:
#                 User        Item  Rating     Timestamp
# 2162   A5JLAU2ARJ0BO  1400532655     1.0  1.291334e+09
# 7381  A2AEZQ3DGBBLPR  B000000O48     5.0  1.038874e+09
# 7448  A2R6RA8FRBS608  B000001OL6     4.0  1.209514e+09
# 7748   A680RUE1FDO8B  B000001OMI     5.0  1.227744e+09
# 7789  A11D1KHM7DVOQK  B000001OMN     2.0  1.167350e+09

# %%
rv.shape
# Out:
# (2913, 4)

# %%
rv.isna().sum()
# Out:
# User         0
# Item         0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
#Spliting the data into 70/30

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(rv, test_size = 0.30, random_state=0)

# %%
#Building colleberative filtering based recommendation system

# %%
# !pip install Recommenders
# Out:
# ...
#   Could not find a version that satisfies the requirement Recommenders (from versions: )
# No matching distribution found for Recommenders

# %%
import Recommenders
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-235aa6b85fd9> in <module>
# ----> 1 import Recommenders
#
# ModuleNotFoundError: No module named 'Recommenders'
